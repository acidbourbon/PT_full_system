# %%
import ROOT
import os
from my_utils import *
from fst import *
import numpy as np
import db 
import pasttrec_ctrl as ptc


data_dir = make_data_dir()

#from ROOT import gInterpreter, gSystem
#gInterpreter.ProcessLine('#include "/workdir/my_event.h"')

import tdc_daq as td


print(data_dir)
for my_board in db.board_list():
    db.enable_board(my_board)    
    db.unset_standby_board(my_board)
    #db.disable_board(my_board)
    #ptc.init_board_by_name(my_board)
    #ptc.set_threshold_for_board_by_name(my_board,5)

ptc.init_active_boards()
td.enable_tdc_channels_of_active_boards()

#set spike rejection for pasttrec tdc channels:
#setup = db.get_setup_json()
#setup["global_settings"]["spike_rejection"] = 33
#print( setup["global_settings"]["spike_rejection"] )
#db.write_setup_json(setup)
#db.write_go4_settings_h()
# Out:
# Welcome to JupyROOT 6.14/04
# /workdir/jupyter/tot_data_taking_data

# %%
##################################################
##   clear data dir, copy root file or measure fresh    ##
##################################################
import hameg_trb 


#data set 2
#all boards on threshold 30, take_data(time=480)
#spike rejection = 15 ns
#HV=1600
#ptime=10
#pt_gain_list = [ 1, 2, 4 ]
#pt_threshold_list = [ 8, 10, 13, 15, 18, 20, 25, 30, 35, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#########################################################################
#data set 3
#all other boards standby,  take_data(time=960)
#spike rejection = 15 ns
#HV=1600
#ptime=15
#pt_gain_list = [ 1, 2, 4 ]
#pt_threshold_list = [ 8, 10, 13, 15, 18, 20, 25, 30, 35, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#########################################################################
#data set 4
#all other boards standby,  take_data(time=480)
#spike rejection = 30 ns
#HV=16002
#ptime=15
#pt_gain_list = [ 1, 2, 4 ]
#pt_threshold_list = [ 8, 10, 13, 15, 18, 20, 25, 30, 35, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#########################################################################
#data set 5
#all other boards standby,  take_data(time=300)
#spike rejection = 15 ns
#HV=1600
#ptime=15
#pt_gain_list = [ 4 ]
#pt_threshold_list = [ 10, 20, 30, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#boards_scan_list = ['0010', '0015', '0016', '0017', '0020', '0023', '0030', '0029', '0027', '0025', '0026', '0022', '0003', '0014', '0021', '0018', '0006', '0028', '0008', '0005']

#########################################################################
dataset_id = 74
# 49 same like 48 but with noise shield again on board 007 = 010
# 50, boards on scan for gain 2,4 thr 35 board with shield
# 57, boards on scan for gain 2,4 thr 35 boards 101, 108
# 59, full paramete scan gain+peakingtime+threshold boards 101, 108
# 60,repeat 57: boards on scan for gain 2,4 thr 35 boards 101, 108
# 61 boards on scan for gain 2,4 thr 15,20,30,50 boards 101, 108
# 62 threshold scan for gain 1,2,4 pktime 10,15,20 boards 101, 108

# 66 threshold scan for gain 2 pktime 15 boards 101, 110  
# 67 boards on scan for gain 2,4 thr 20,30 boards 101, 110
# 68, repeat of 67 with Ferrit on TDF cable 110 ( boards on scan for gain 2,4 thr 30 boards 101, 110 )
# 69 threshold scan for gain 1,2,4 pktime 15 boards 101, 110  
# 69+ boards on scan for gain 4 thr 35,
# 70 boards on scan for gain 4 thr 30,31,32 three different boards activate sequences(random) boards 101, 110
# 71 threshold scan for gain 4 pktime 15 boards 101, 110 , all other boards inactive 2 round Ferrites  on LVDS cable
# 73 threshold scan for gain 4 pktime 15 boards 101, 110 , all other boards active 4 flat Ferrites on LVDS cable
# 74 repeat 70 now with  4 flat Ferrites on LVDS cable

# 51 board with shield, parameter scan
# 52, boards on scan for gain 2 thr 25,30 board with shield
# MDC settings:
HV=1600
data_taking_duration = 600
# set PASTTREC settings:
# peakintime: 10, 15, 20 (ns)
# gain: 1, 2, 4
# threshold: 1,2,3 .... 127
# spike rejection 10 ,15, 20 ,33,99 all int possible (ns)

#ptime_list = [ 10, 15, 20 ]
ptime_list = [ 15 ]
# set PASTTREC default threshold for the measurement
# pt_gain_list = [ 1, 2, 4 ]
pt_gain_list = [4]  
#pt_threshold_list = [  15, 20, 30, 50 ]
#pt_threshold_list = [ 10,15,20,25,30,35,40,50,70]
pt_threshold_list = [  30,31,32 ]
spike_reject_list = [15]
#spike_reject_list = [10, 15, 20, 30]

#board_list = [ "0009","0010","0011", "0002","0004","0007", "0015","0016","0017" ]
board_list = [ "0101","0110"]
boards_to_activate_on_one_step = 1

name = board_list[0]

from cw_pasttrec_functions import *
## define sequence of boards to activate in scan.
#boards_scan_list = generate_neighbouring_FPC_board_list(name)
boards_scan_list = generate_neighbouring_w_board_list(name)
#boards_scan_list = db.board_list()
# boards_scan_list = ['0110']
# boards_scan_list = ['0110', '0011', '0010', '0015', '0016', '0009', '0017', '0020', '0023', '0030', '0110', '0029', '0002', '0027', '0101', '0025', '0004', '0026', '0022', '0003', '0014', '0021', '0018', '0104', '0006', '0028', '0103', '0102', '0008', '0005']
#boards_scan_list = ['0010', '0101', '0011', '0002', '0009', '0004', '0015', '0027', '0016', '0025', '0017', '0026', '0022', '0020', '0003', '0023', '0030', '0014', '0021', '0029', '0018', '0104', '0103', '0006', '0008', '0102', '0028']
#boards_scan_list = ['0010', '0011', '0009', '0015', '0016', '0017', '0020', '0023', '0030', '0029', '0101', '0002', '0004', '0027', '0025', '0026', '0022', '0003', '0014', '0021', '0018', '0104', '0006', '0028']
# boards_scan_list = ['0010', '0009', '0011', '0015', '0016', '0017', '0020', '0023', '0030', '0029', '0027', '0002', '0004', '0025', '0026', '0022', '0003', '0014', '0021', '0018', '0006', '0028', '0008', '0005']
#boards_scan_list = ['0014', '0005', '0021', '0022', '0025', '0003', '0026', '0027', '0008', '0004', '0002', '0101', '0029', '0030', '0028', '0023', '0020', '0017', '0016', '0006', '0015', '0010', '0011', '0009']


data_file_list = []
current_list = []
volt_list = []
current_list2 = []
volt_list2 = []

#for my_board in db.board_list():
#            db.unset_standby_board(my_board)
message = " total measurement time estimated [h] = {:.2f}".format(data_taking_duration/3600*len(spike_reject_list)*len(ptime_list)*len(pt_gain_list)*len(pt_threshold_list)*len(boards_scan_list)/boards_to_activate_on_one_step)
print(message)
alert(message)

for spike_reject in spike_reject_list:
 setup = db.get_setup_json()
 setup["global_settings"]["spike_rejection"] = spike_reject
 db.write_setup_json(setup)
 db.write_go4_settings_h()
 for ptime in ptime_list: 
  for pt_gain in pt_gain_list:     
   for pt_threshold in pt_threshold_list:    
    for my_board in db.board_list():
        db.set_standby_board(my_board)
    import random
    random.shuffle(boards_scan_list)
    iboard = -boards_to_activate_on_one_step
    for p in range(0,int(len(boards_scan_list)/boards_to_activate_on_one_step)): 
        iboard += boards_to_activate_on_one_step
        for my_board in db.board_list():
            for p_act in range(0,boards_to_activate_on_one_step):
                if my_board == boards_scan_list[iboard+p_act]:
                    db.unset_standby_board(my_board)
                    db.enable_board(my_board)
        # enable data taking boards:
        for my_board in board_list:
            db.unset_standby_board(my_board)
            db.enable_board(my_board)
        td.enable_tdc_channels_of_active_boards()
        ptc.init_boards_by_name(db.board_list())    
        #ptc.init_active_boards()
        ptc.init_boards_by_name(board_list, ptime, pt_gain, pt_threshold)   
                        # init_boards_by_name(board_list,pktime=-1,gain=-1,threshold=-1):
        for name in board_list:
            ptc.set_threshold_for_board_by_name(name,pt_threshold)
        print(hameg_trb.get_curr(3), hameg_trb.get_curr(4))
        #take_data(events=20000)
        # uses only trigger by TDC 0350 channel 49 as the reference. 
        # either Scitillator inpot or puls generator input to this channel, needs to be used
        take_data(time=data_taking_duration)
        #import time as time
        #time.sleep(4)
        
        
        current_list += [ hameg_trb.get_curr(3) ]
        volt_list += [ hameg_trb.get_volt(3) ]
        current_list2 += [ hameg_trb.get_curr(4) ]
        volt_list2 += [ hameg_trb.get_volt(4) ] 

        print(hameg_trb.get_curr(3), hameg_trb.get_curr(4))
     # clear_data_dir()
        data_file = "{:s}/ID{:d}_HV{:d}V_ptime_{:d}_thr_{:d}_gain_{:d}_boardsON_{:d}_sr_{:d}.root".format(data_dir,dataset_id,HV,ptime,pt_threshold,pt_gain,iboard,spike_reject)
        print(data_file)
        os.system("cp /workdir/joint_tree.root {:s}".format(data_file))
        data_file_list.append(data_file)

  # write data file list to disk, for later analysis
import pickle
with open("{:s}/datasetID_{:d}_list.pickle".format(data_dir,dataset_id), 'wb') as fp:
    pickle.dump(data_file_list, fp)  
print(fp)
archive(label="ToT_data_taking_ID{:d}".format(dataset_id))
# Out:
# 23 boards to activate, sequence of activation, boards list:
# ['0101', '0004', '0009', '0002', '0011', '0027', '0110', '0025', '0016', '0026', '0022', '0003', '0014', '0021', '0029', '0104', '0103', '0006', '0008', '0102', '0028', '0005', '0108']
#  total measurement time estimated [h] = 11.50
# <script>alert(' total measurement time estimated [h] = 11.50');</script>
# 2.369 2.616
# 2.369 2.628
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_0_sr_15.root
# 2.369 2.628
# 2.369 2.609
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_1_sr_15.root
# 2.369 2.61
# 2.369 2.613
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_2_sr_15.root
# 2.369 2.613
# 2.369 2.58
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_3_sr_15.root
# 2.369 2.579
# 2.369 2.343
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_4_sr_15.root
# 2.369 2.347
# 2.369 2.509
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_5_sr_15.root
# 2.369 2.509
# 2.369 2.591
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_6_sr_15.root
# 2.369 2.59
# 2.369 2.602
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_7_sr_15.root
# 2.369 2.601
# 2.369 2.617
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_8_sr_15.root
# 2.369 2.618
# 2.369 2.598
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_9_sr_15.root
# 2.369 2.597
# 2.369 2.574
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_10_sr_15.root
# 2.369 2.574
# 2.369 2.572
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_11_sr_15.root
# 2.369 2.572
# 2.369 2.31
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_12_sr_15.root
# 2.369 2.322
# 2.369 2.401
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_13_sr_15.root
# 2.369 2.394
# 2.369 2.376
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_14_sr_15.root
# 2.369 2.371
# 2.369 2.374
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_15_sr_15.root
# 2.369 2.373
# 2.369 2.729
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_16_sr_15.root
# 2.369 2.729
# 2.369 2.722
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_17_sr_15.root
# 2.369 2.722
# 2.369 2.696
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_18_sr_15.root
# 2.369 2.694
# 2.369 2.677
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_19_sr_15.root
# 2.369 2.677
# 2.369 2.661
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_20_sr_15.root
# 2.369 2.66
# 2.368 2.649
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_21_sr_15.root
# 2.368 2.647
# 2.368 2.611
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_22_sr_15.root
# 2.369 2.612
# 2.369 2.583
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_0_sr_15.root
# 2.369 2.583
# 2.369 2.584
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_1_sr_15.root
# 2.369 2.583
# 2.369 2.564
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_2_sr_15.root
# 2.369 2.558
# 2.369 2.494
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_3_sr_15.root
# 2.369 2.493
# 2.369 2.751
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_4_sr_15.root
# 2.369 2.751
# 2.369 2.745
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_5_sr_15.root
# 2.369 2.745
# 2.369 2.728
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_6_sr_15.root
# 2.369 2.728
# 2.369 2.695
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_7_sr_15.root
# 2.369 2.71
# 2.369 2.704
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_8_sr_15.root
# 2.369 2.704
# 2.369 2.705
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_9_sr_15.root
# 2.369 2.705
# 2.369 2.491
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_10_sr_15.root
# 2.369 2.491
# 2.369 2.462
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_11_sr_15.root
# 2.369 2.463
# 2.369 2.322
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_12_sr_15.root
# 2.369 2.34
# 2.369 2.631
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_13_sr_15.root
# 2.369 2.632
# 2.369 2.605
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_14_sr_15.root
# 2.369 2.606
# 2.369 2.578
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_15_sr_15.root
# 2.369 2.578
# 2.369 2.574
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_16_sr_15.root
# 2.369 2.574
# 2.369 2.582
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_17_sr_15.root
# 2.369 2.583
# 2.369 2.586
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_18_sr_15.root
# 2.369 2.589
# 2.369 2.577
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_19_sr_15.root
# 2.369 2.578
# 2.369 2.442
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_20_sr_15.root
# 2.369 2.456
# 2.369 2.48
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_21_sr_15.root
# 2.369 2.48
# 2.368 2.462
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_22_sr_15.root
# 2.369 2.462
# 2.369 2.442
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_0_sr_15.root
# 2.369 2.444
# 2.369 2.445
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_1_sr_15.root
# 2.369 2.446
# 2.369 2.457
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_2_sr_15.root
# 2.369 2.456
# 2.369 2.668
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_3_sr_15.root
# 2.369 2.669
# 2.369 2.625
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_4_sr_15.root
# 2.369 2.624
# 2.369 2.473
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_5_sr_15.root
# 2.369 2.464
# 2.369 2.467
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_6_sr_15.root
# 2.369 2.466
# 2.369 2.457
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_7_sr_15.root
# 2.369 2.458
# 2.369 2.47
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_8_sr_15.root
# 2.369 2.469
# 2.369 2.455
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_9_sr_15.root
# 2.369 2.456
# 2.369 2.45
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_10_sr_15.root
# 2.369 2.446
# 2.369 2.461
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_11_sr_15.root
# 2.369 2.459
# 2.369 2.607
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_12_sr_15.root
# 2.369 2.608
# 2.369 2.637
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_13_sr_15.root
# 2.369 2.638
# 2.369 2.63
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_14_sr_15.root
# 2.369 2.629
# 2.369 2.644
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_15_sr_15.root
# 2.369 2.643
# 2.369 2.636
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_16_sr_15.root
# 2.369 2.637
# 2.369 2.642
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_17_sr_15.root
# 2.369 2.643
# 2.369 2.631
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_18_sr_15.root
# 2.369 2.632
# 2.369 2.636
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_19_sr_15.root
# 2.369 2.636
# 2.369 2.631
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_20_sr_15.root
# 2.369 2.631
# 2.37 2.635
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_21_sr_15.root
# 2.369 2.633
# 2.37 2.626
# /workdir/jupyter/tot_data_taking_data/ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_22_sr_15.root
# <_io.BufferedWriter name='/workdir/jupyter/tot_data_taking_data/datasetID_74_list.pickle'>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '/workdir/*.root': No such file or directory
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
# ...
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')        
plt.scatter(range(0,len(current_list)),current_list)    
plt.xlabel("data set")
plt.ylabel("supply current [A] of all PASTTREC boards 101 (5V layer 2) ")
plt.show()
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k') 
plt.scatter(range(0,len(current_list2)),current_list2)        
plt.xlabel("data set")
plt.ylabel("supply current [A] of PASTTREC board 110 (5V layer 3) ")
plt.show()

plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k') 
plt.scatter(range(0,len(volt_list)),volt_list,alpha=0.3,label = "5V layer 2")
plt.scatter(range(0,len(volt_list2)),volt_list2,alpha=0.3,label = "5V layer 3")      
plt.xlabel("data set")
plt.ylabel("supply voltage [V] of all PASTTREC boards  ")
plt.legend()
plt.show()

# %%
archive(label="ID_{:d}_tot_data_powersupply_trend".format(dataset_id))
# Out:
# archived to ./archive/2020-06-12_11-14-01_tot_data_taking_ID_74_tot_data_powersupply_trend

# %%
import pickle
with open("{:s}/datasetID_{:d}_list.pickle".format(data_dir,dataset_id), 'wb') as fp:
    pickle.dump(data_file_list, fp)  
print(fp)

##################################################
##               slurp root file                ##
##################################################
 
#with open ('/workdir/jupyter/tot_data_taking_data/HV1600V_ptime_15_threshold_50_gain_4_boardsON_23.rootlist.pickle', 'rb') as fp:
 #   data_file_list = pickle.load(fp)
    

#f = ROOT.TFile("/workdir/tree_out.root".format(data_dir))
#tree = f.Get("TDC_1503")
#print("data entries TDC_1503: " + str(tree.GetEntries()))
i = -1
clist = [None]*100
print("data file   ,", "tot_mostprob", "signalcounts", "noisecounts", "sn_ratio", "significance")
    
for data_file in data_file_list:
    i += 1
    #print(data_file)
    f = ROOT.TFile("{:s}".format(data_file))
    tree = f.Get("joint_tree")
    #print("data entries: " + str(tree.GetEntries()))
    ## plot data:
    clist[i] = ROOT.TCanvas("myCanvasName"+str(i),str(data_file),800,600)
    tree.Draw("tot>>htot(300,0,400)","chan > 150300 && chan < 150316")
    tree.Draw("tot>>htot2(300,0,400)","chan > 035300 && chan < 035316","same")    
    clist[i].Draw()
    htot = f.Get("htot")
    htot2 = f.Get("htot2")
    clist[i].SetLogy()
    htot.GetXaxis().SetTitle("ToT [ns]")
    htot.GetYaxis().SetTitle("counts")
    htot.SetTitle(data_file.strip("workdir/jupyter/tot_data_taking_data"))
    htot.SetLineColor(6)
    htot.DrawCopy("")
    htot2.DrawCopy("same")
    tot_mostprob = htot.GetXaxis().GetBinCenter(htot.GetMaximumBin())
    
    signalcounts  = htot.Integral(htot.FindBin(50),htot.GetNbinsX())
    noisecounts   = htot.Integral(1,htot.FindBin(50))
    if noisecounts == 0:
        sn_ratio = -1
        significance = -1
    else:
        sn_ratio = signalcounts/noisecounts
        significance = signalcounts/np.sqrt(signalcounts+noisecounts)
    print(  htot.GetTitle() , "| ",  tot_mostprob,"| ", signalcounts,"| ", noisecounts,"| ", "{:.2f}".format(sn_ratio),"| ", "{:.2f}".format(significance))
# Out:
# <_io.BufferedWriter name='/workdir/jupyter/tot_data_taking_data/datasetID_74_list.pickle'>
# data file   , tot_mostprob signalcounts noisecounts sn_ratio significance
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_0_sr_15. |  15.333333333333332 |  591.0 |  194.0 |  3.05 |  21.09
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_1_sr_15. |  15.333333333333332 |  666.0 |  216.0 |  3.08 |  22.43
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_2_sr_15. |  16.666666666666668 |  621.0 |  196.0 |  3.17 |  21.73
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_3_sr_15. |  15.333333333333332 |  641.0 |  258.0 |  2.48 |  21.38
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_4_sr_15. |  15.333333333333332 |  629.0 |  198.0 |  3.18 |  21.87
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_5_sr_15. |  16.666666666666668 |  642.0 |  172.0 |  3.73 |  22.50
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_6_sr_15. |  15.333333333333332 |  679.0 |  254.0 |  2.67 |  22.23
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_7_sr_15. |  16.666666666666668 |  558.0 |  209.0 |  2.67 |  20.15
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_8_sr_15. |  16.666666666666668 |  581.0 |  228.0 |  2.55 |  20.43
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_9_sr_15. |  16.666666666666668 |  671.0 |  238.0 |  2.82 |  22.26
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_10_sr_15. |  16.666666666666668 |  589.0 |  183.0 |  3.22 |  21.20
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_11_sr_15. |  15.333333333333332 |  645.0 |  205.0 |  3.15 |  22.12
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_12_sr_15. |  16.666666666666668 |  598.0 |  182.0 |  3.29 |  21.41
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_13_sr_15. |  15.333333333333332 |  624.0 |  164.0 |  3.80 |  22.23
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_14_sr_15. |  15.333333333333332 |  655.0 |  189.0 |  3.47 |  22.55
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_15_sr_15. |  15.333333333333332 |  644.0 |  267.0 |  2.41 |  21.34
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_16_sr_15. |  15.333333333333332 |  631.0 |  180.0 |  3.51 |  22.16
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_17_sr_15. |  15.333333333333332 |  637.0 |  173.0 |  3.68 |  22.38
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_18_sr_15. |  16.666666666666668 |  665.0 |  224.0 |  2.97 |  22.30
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_19_sr_15. |  15.333333333333332 |  727.0 |  216.0 |  3.37 |  23.67
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_20_sr_15. |  18.0 |  695.0 |  181.0 |  3.84 |  23.48
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_21_sr_15. |  15.333333333333332 |  635.0 |  168.0 |  3.78 |  22.41
# ID74_HV1600V_ptime_15_thr_30_gain_4_boardsON_22_sr_15. |  15.333333333333332 |  648.0 |  206.0 |  3.15 |  22.17
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_0_sr_15. |  15.333333333333332 |  711.0 |  104.0 |  6.84 |  24.91
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_1_sr_15. |  149.99999999999997 |  671.0 |  113.0 |  5.94 |  23.96
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_2_sr_15. |  157.99999999999997 |  716.0 |  78.0 |  9.18 |  25.41
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_3_sr_15. |  144.66666666666666 |  648.0 |  77.0 |  8.42 |  24.07
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_4_sr_15. |  149.99999999999997 |  654.0 |  90.0 |  7.27 |  23.98
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_5_sr_15. |  144.66666666666666 |  640.0 |  72.0 |  8.89 |  23.99
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_6_sr_15. |  147.33333333333331 |  710.0 |  100.0 |  7.10 |  24.95
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_7_sr_15. |  152.66666666666666 |  671.0 |  96.0 |  6.99 |  24.23
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_8_sr_15. |  16.666666666666668 |  690.0 |  122.0 |  5.66 |  24.21
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_9_sr_15. |  147.33333333333331 |  721.0 |  105.0 |  6.87 |  25.09
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_10_sr_15. |  143.33333333333331 |  710.0 |  119.0 |  5.97 |  24.66
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_11_sr_15. |  147.33333333333331 |  708.0 |  113.0 |  6.27 |  24.71
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_12_sr_15. |  145.99999999999997 |  668.0 |  67.0 |  9.97 |  24.64
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_13_sr_15. |  16.666666666666668 |  590.0 |  70.0 |  8.43 |  22.97
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_14_sr_15. |  19.333333333333332 |  620.0 |  112.0 |  5.54 |  22.92
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_15_sr_15. |  20.666666666666668 |  656.0 |  122.0 |  5.38 |  23.52
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_16_sr_15. |  147.33333333333331 |  714.0 |  147.0 |  4.86 |  24.33
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_17_sr_15. |  152.66666666666666 |  735.0 |  110.0 |  6.68 |  25.28
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_18_sr_15. |  149.99999999999997 |  674.0 |  96.0 |  7.02 |  24.29
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_19_sr_15. |  140.66666666666666 |  670.0 |  79.0 |  8.48 |  24.48
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_20_sr_15. |  151.33333333333331 |  746.0 |  103.0 |  7.24 |  25.60
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_21_sr_15. |  145.99999999999997 |  704.0 |  137.0 |  5.14 |  24.28
# ID74_HV1600V_ptime_15_thr_31_gain_4_boardsON_22_sr_15. |  145.99999999999997 |  628.0 |  75.0 |  8.37 |  23.69
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_0_sr_15. |  148.66666666666666 |  662.0 |  52.0 |  12.73 |  24.77
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_1_sr_15. |  149.99999999999997 |  726.0 |  94.0 |  7.72 |  25.35
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_2_sr_15. |  159.33333333333331 |  708.0 |  59.0 |  12.00 |  25.56
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_3_sr_15. |  149.99999999999997 |  662.0 |  49.0 |  13.51 |  24.83
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_4_sr_15. |  148.66666666666666 |  612.0 |  68.0 |  9.00 |  23.47
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_5_sr_15. |  145.99999999999997 |  739.0 |  56.0 |  13.20 |  26.21
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_6_sr_15. |  148.66666666666666 |  639.0 |  89.0 |  7.18 |  23.68
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_7_sr_15. |  164.66666666666666 |  659.0 |  51.0 |  12.92 |  24.73
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_8_sr_15. |  155.33333333333331 |  690.0 |  82.0 |  8.41 |  24.83
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_9_sr_15. |  149.99999999999997 |  637.0 |  37.0 |  17.22 |  24.54
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_10_sr_15. |  160.66666666666666 |  698.0 |  62.0 |  11.26 |  25.32
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_11_sr_15. |  149.99999999999997 |  619.0 |  58.0 |  10.67 |  23.79
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_12_sr_15. |  157.99999999999997 |  677.0 |  47.0 |  14.40 |  25.16
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_13_sr_15. |  147.33333333333331 |  723.0 |  80.0 |  9.04 |  25.51
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_14_sr_15. |  168.66666666666666 |  687.0 |  72.0 |  9.54 |  24.94
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_15_sr_15. |  159.33333333333331 |  637.0 |  55.0 |  11.58 |  24.22
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_16_sr_15. |  159.33333333333331 |  635.0 |  27.0 |  23.52 |  24.68
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_17_sr_15. |  147.33333333333331 |  612.0 |  43.0 |  14.23 |  23.91
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_18_sr_15. |  152.66666666666666 |  690.0 |  59.0 |  11.69 |  25.21
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_19_sr_15. |  153.99999999999997 |  644.0 |  39.0 |  16.51 |  24.64
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_20_sr_15. |  151.33333333333331 |  669.0 |  46.0 |  14.54 |  25.02
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_21_sr_15. |  159.33333333333331 |  681.0 |  61.0 |  11.16 |  25.00
# ID74_HV1600V_ptime_15_thr_32_gain_4_boardsON_22_sr_15. |  156.66666666666666 |  659.0 |  48.0 |  13.73 |  24.78
# Warning in <TClass::Init>: no dictionary for class Event is available
# Warning in <TClass::Init>: no dictionary for class Hit is available

# %%
##################################################
##             overview TDC 0x0351              ##
##################################################
c = ROOT.TCanvas("myCanvasName","The Canvas Title",640,480)

tdc=1503
disp_channels = 65
#tree.Draw("chan:t1","","lego2")
tree.Draw("chan:tot>>tot_meta(1000,-300,800,{:d},{:d},{:d})".format(disp_channels,tdc*100,tdc*100+disp_channels),"","colz")
c.Draw()

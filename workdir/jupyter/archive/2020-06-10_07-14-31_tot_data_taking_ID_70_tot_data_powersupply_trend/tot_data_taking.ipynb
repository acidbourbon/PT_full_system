# %%
import ROOT
import os
from my_utils import *
from fst import *
import numpy as np
import db 
import pasttrec_ctrl as ptc


data_dir = make_data_dir()

#from ROOT import gInterpreter, gSystem
#gInterpreter.ProcessLine('#include "/workdir/my_event.h"')

import tdc_daq as td


print(data_dir)
for my_board in db.board_list():
    db.enable_board(my_board)    
    db.unset_standby_board(my_board)
    #db.disable_board(my_board)
    #ptc.init_board_by_name(my_board)
    #ptc.set_threshold_for_board_by_name(my_board,5)

ptc.init_active_boards()
td.enable_tdc_channels_of_active_boards()

#set spike rejection for pasttrec tdc channels:
#setup = db.get_setup_json()
#setup["global_settings"]["spike_rejection"] = 33
#print( setup["global_settings"]["spike_rejection"] )
#db.write_setup_json(setup)
#db.write_go4_settings_h()
# Out:
# Welcome to JupyROOT 6.14/04
# /workdir/jupyter/tot_data_taking_data

# %%
##################################################
##   clear data dir, copy root file or measure fresh    ##
##################################################
import hameg_trb 


#data set 2
#all boards on threshold 30, take_data(time=480)
#spike rejection = 15 ns
#HV=1600
#ptime=10
#pt_gain_list = [ 1, 2, 4 ]
#pt_threshold_list = [ 8, 10, 13, 15, 18, 20, 25, 30, 35, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#########################################################################
#data set 3
#all other boards standby,  take_data(time=960)
#spike rejection = 15 ns
#HV=1600
#ptime=15
#pt_gain_list = [ 1, 2, 4 ]
#pt_threshold_list = [ 8, 10, 13, 15, 18, 20, 25, 30, 35, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#########################################################################
#data set 4
#all other boards standby,  take_data(time=480)
#spike rejection = 30 ns
#HV=16002
#ptime=15
#pt_gain_list = [ 1, 2, 4 ]
#pt_threshold_list = [ 8, 10, 13, 15, 18, 20, 25, 30, 35, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#########################################################################
#data set 5
#all other boards standby,  take_data(time=300)
#spike rejection = 15 ns
#HV=1600
#ptime=15
#pt_gain_list = [ 4 ]
#pt_threshold_list = [ 10, 20, 30, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#boards_scan_list = ['0010', '0015', '0016', '0017', '0020', '0023', '0030', '0029', '0027', '0025', '0026', '0022', '0003', '0014', '0021', '0018', '0006', '0028', '0008', '0005']

#########################################################################
dataset_id = 70
# 49 same like 48 but with noise shield again on board 007 = 010
# 50, boards on scan for gain 2,4 thr 35 board with shield
# 57, boards on scan for gain 2,4 thr 35 boards 101, 108
# 59, full paramete scan gain+peakingtime+threshold boards 101, 108
# 60,repeat 57: boards on scan for gain 2,4 thr 35 boards 101, 108
# 61 boards on scan for gain 2,4 thr 15,20,30,50 boards 101, 108
# 62 threshold scan for gain 1,2,4 pktime 10,15,20 boards 101, 108

# 66 threshold scan for gain 2 pktime 15 boards 101, 110  
# 67 boards on scan for gain 2,4 thr 20,30 boards 101, 110
# 68, repeat of 67 with Ferrit on TDF cable 110 ( boards on scan for gain 2,4 thr 30 boards 101, 110 )
# 69 threshold scan for gain 1,2,4 pktime 15 boards 101, 110  
# 69+ boards on scan for gain  thr 35,
# 70 boards on scan for gain  thr 30,31,32 three different boards activate sequences(random) boards 101, 110

# 51 board with shield, parameter scan
# 52, boards on scan for gain 2 thr 25,30 board with shield
# MDC settings:
HV=1600
data_taking_duration = 900
# set PASTTREC settings:
# peakintime: 10, 15, 20 (ns)
# gain: 1, 2, 4
# threshold: 1,2,3 .... 127
# spike rejection 10 ,15, 20 ,33,99 all int possible (ns)

#ptime_list = [ 10, 15, 20 ]
ptime_list = [ 15 ]
# set PASTTREC default threshold for the measurement
#pt_gain_list = [ 1,  2, 4 ]
pt_gain_list = [4]  
#pt_threshold_list = [  15, 20, 30, 50 ]
#pt_threshold_list = [ 10,15,20,25,30,35,40,50,70]
pt_threshold_list = [  30,31,32 ]
spike_reject_list = [15]
#spike_reject_list = [10, 15, 20, 30]

#board_list = [ "0009","0010","0011", "0002","0004","0007", "0015","0016","0017" ]
board_list = [ "0101","0110"]
boards_to_activate_on_one_step = 1

name = board_list[0]

from cw_pasttrec_functions import *
## define sequence of boards to activate in scan.
#boards_scan_list = generate_neighbouring_FPC_board_list(name)
boards_scan_list = generate_neighbouring_w_board_list(name)
#boards_scan_list = db.board_list()
# boards_scan_list = ['0110']
# boards_scan_list = ['0110', '0011', '0010', '0015', '0016', '0009', '0017', '0020', '0023', '0030', '0110', '0029', '0002', '0027', '0101', '0025', '0004', '0026', '0022', '0003', '0014', '0021', '0018', '0104', '0006', '0028', '0103', '0102', '0008', '0005']
#boards_scan_list = ['0010', '0101', '0011', '0002', '0009', '0004', '0015', '0027', '0016', '0025', '0017', '0026', '0022', '0020', '0003', '0023', '0030', '0014', '0021', '0029', '0018', '0104', '0103', '0006', '0008', '0102', '0028']
#boards_scan_list = ['0010', '0011', '0009', '0015', '0016', '0017', '0020', '0023', '0030', '0029', '0101', '0002', '0004', '0027', '0025', '0026', '0022', '0003', '0014', '0021', '0018', '0104', '0006', '0028']
# boards_scan_list = ['0010', '0009', '0011', '0015', '0016', '0017', '0020', '0023', '0030', '0029', '0027', '0002', '0004', '0025', '0026', '0022', '0003', '0014', '0021', '0018', '0006', '0028', '0008', '0005']
#boards_scan_list = ['0014', '0005', '0021', '0022', '0025', '0003', '0026', '0027', '0008', '0004', '0002', '0101', '0029', '0030', '0028', '0023', '0020', '0017', '0016', '0006', '0015', '0010', '0011', '0009']


data_file_list = []
current_list = []
volt_list = []
current_list2 = []
volt_list2 = []

#for my_board in db.board_list():
#            db.unset_standby_board(my_board)
message = " total measurement time estimated [h] = {:.2f}".format(data_taking_duration/3600*len(spike_reject_list)*len(ptime_list)*len(pt_gain_list)*len(pt_threshold_list)*len(boards_scan_list)/boards_to_activate_on_one_step)
print(message)
alert(message)

for spike_reject in spike_reject_list:
 setup = db.get_setup_json()
 setup["global_settings"]["spike_rejection"] = spike_reject
 db.write_setup_json(setup)
 db.write_go4_settings_h()
 for ptime in ptime_list: 
  for pt_gain in pt_gain_list:     
   for pt_threshold in pt_threshold_list:    
    for my_board in db.board_list():
        db.set_standby_board(my_board)
    import random
    random.shuffle(boards_scan_list)
    iboard = -boards_to_activate_on_one_step
    for p in range(0,int(len(boards_scan_list)/boards_to_activate_on_one_step)): 
        iboard += boards_to_activate_on_one_step
        for my_board in db.board_list():
            for p_act in range(0,boards_to_activate_on_one_step):
                if my_board == boards_scan_list[iboard+p_act]:
                    db.unset_standby_board(my_board)
                    db.enable_board(my_board)
        # enable data taking boards:
        for my_board in board_list:
            db.unset_standby_board(my_board)
            db.enable_board(my_board)
        td.enable_tdc_channels_of_active_boards()
        ptc.init_boards_by_name(db.board_list())    
        #ptc.init_active_boards()
        ptc.init_boards_by_name(board_list, ptime, pt_gain, pt_threshold)   
                        # init_boards_by_name(board_list,pktime=-1,gain=-1,threshold=-1):
        for name in board_list:
            ptc.set_threshold_for_board_by_name(name,pt_threshold)
        print(hameg_trb.get_curr(3), hameg_trb.get_curr(4))
        #take_data(events=20000)
        # uses only trigger by TDC 0350 channel 49 as the reference. 
        # either Scitillator inpot or puls generator input to this channel, needs to be used
        take_data(time=data_taking_duration)
        #import time as time
        #time.sleep(4)
        
        
        current_list += [ hameg_trb.get_curr(3) ]
        volt_list += [ hameg_trb.get_volt(3) ]
        current_list2 += [ hameg_trb.get_curr(4) ]
        volt_list2 += [ hameg_trb.get_volt(4) ] 

        print(hameg_trb.get_curr(3), hameg_trb.get_curr(4))
     # clear_data_dir()
        data_file = "{:s}/ID{:d}_HV{:d}V_ptime_{:d}_thr_{:d}_gain_{:d}_boardsON_{:d}_sr_{:d}.root".format(data_dir,dataset_id,HV,ptime,pt_threshold,pt_gain,iboard,spike_reject)
        print(data_file)
        os.system("cp /workdir/joint_tree.root {:s}".format(data_file))
        data_file_list.append(data_file)

  # write data file list to disk, for later analysis
import pickle
with open("{:s}/datasetID_{:d}_list.pickle".format(data_dir,dataset_id), 'wb') as fp:
    pickle.dump(data_file_list, fp)  
print(fp)
archive(label="ToT_data_taking_ID{:d}".format(dataset_id))
# Out:
# 24 boards to activate, sequence of activation, boards list:
# ['0101', '0004', '0009', '0002', '0011', '0027', '0025', '0016', '0026', '0017', '0022', '0003', '0014', '0030', '0021', '0110', '0029', '0006', '0008', '0108', '0028', '0005', '0105', '0106']
#  total measurement time estimated [h] = 18.00
# <script>alert(' total measurement time estimated [h] = 18.00');</script>
# 2.382 0.6959
# 2.382 0.6969
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_0_sr_15.root
# 2.382 0.6968
# 2.382 0.6947
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_1_sr_15.root
# 2.381 0.6948
# 2.382 0.6958
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_2_sr_15.root
# 2.381 0.6958
# 2.382 0.6952
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_3_sr_15.root
# 2.381 0.695
# 2.382 0.6939
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_4_sr_15.root
# 2.381 0.6939
# 2.382 0.6942
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_5_sr_15.root
# 2.381 0.6941
# 2.382 0.6937
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_6_sr_15.root
# 2.381 0.6938
# 2.381 0.6926
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_7_sr_15.root
# 2.381 0.6929
# 2.381 0.6925
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_8_sr_15.root
# 2.381 0.6922
# 2.381 0.6899
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_9_sr_15.root
# 2.381 0.6897
# 2.381 0.6907
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_10_sr_15.root
# 2.381 0.6907
# 2.381 0.6911
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_11_sr_15.root
# 2.381 0.6908
# 2.381 0.6893
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_12_sr_15.root
# 2.381 0.6893
# 2.381 0.6898
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_13_sr_15.root
# 2.381 0.6897
# 2.381 0.6895
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_14_sr_15.root
# 2.381 0.6895
# 2.381 0.688
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_15_sr_15.root
# 2.381 0.6879
# 2.381 0.6871
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_16_sr_15.root
# 2.381 0.6869
# 2.381 0.6859
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_17_sr_15.root
# 2.381 0.6858
# 2.381 0.6862
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_18_sr_15.root
# 2.381 0.6864
# 2.381 0.6855
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_19_sr_15.root
# 2.381 0.6854
# 2.381 0.685
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_20_sr_15.root
# 2.381 0.685
# 2.381 0.684
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_21_sr_15.root
# 2.381 0.684
# 2.381 0.6843
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_22_sr_15.root
# 2.381 0.6843
# 2.381 0.6823
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_23_sr_15.root
# 2.381 0.6825
# 2.382 0.6796
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_0_sr_15.root
# 2.381 0.6797
# 2.382 0.6802
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_1_sr_15.root
# 2.381 0.6804
# 2.382 0.6794
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_2_sr_15.root
# 2.381 0.6794
# 2.382 0.678
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_3_sr_15.root
# 2.381 0.678
# 2.382 0.6771
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_4_sr_15.root
# 2.381 0.6772
# 2.382 0.6781
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_5_sr_15.root
# 2.381 0.678
# 2.382 0.678
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_6_sr_15.root
# 2.381 0.6783
# 2.382 0.6796
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_7_sr_15.root
# 2.381 0.6796
# 2.382 0.6826
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_8_sr_15.root
# 2.381 0.6827
# 2.382 0.684
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_9_sr_15.root
# 2.381 0.6841
# 2.382 0.6822
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_10_sr_15.root
# 2.381 0.6822
# 2.382 0.6825
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_11_sr_15.root
# 2.381 0.6821
# 2.382 0.6811
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_12_sr_15.root
# 2.381 0.6811
# 2.382 0.6779
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_13_sr_15.root
# 2.381 0.678
# 2.382 0.6772
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_14_sr_15.root
# 2.381 0.6769
# 2.382 0.6757
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_15_sr_15.root
# 2.381 0.6756
# 2.382 0.6797
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_16_sr_15.root
# 2.381 0.6797
# 2.382 0.68
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_17_sr_15.root
# 2.381 0.6799
# 2.382 0.6808
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_18_sr_15.root
# 2.381 0.6804
# 2.381 0.6878
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_19_sr_15.root
# 2.381 0.6879
# 2.381 0.6816
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_20_sr_15.root
# 2.381 0.6815
# 2.381 0.6812
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_21_sr_15.root
# 2.381 0.6812
# 2.382 0.677
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_22_sr_15.root
# 2.381 0.6769
# 2.381 0.681
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_23_sr_15.root
# 2.382 0.6812
# 2.382 0.6815
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_0_sr_15.root
# 2.382 0.6814
# 2.382 0.6821
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_1_sr_15.root
# 2.382 0.6819
# 2.382 0.6838
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_2_sr_15.root
# 2.382 0.6839
# 2.382 0.6843
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_3_sr_15.root
# 2.382 0.6843
# 2.382 0.6838
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_4_sr_15.root
# 2.382 0.6836
# 2.382 0.6842
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_5_sr_15.root
# 2.382 0.6842
# 2.382 0.6849
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_6_sr_15.root
# 2.382 0.685
# 2.382 0.6803
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_7_sr_15.root
# 2.382 0.6801
# 2.382 0.6824
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_8_sr_15.root
# 2.382 0.6825
# 2.382 0.6834
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_9_sr_15.root
# 2.382 0.6833
# 2.382 0.6831
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_10_sr_15.root
# 2.382 0.6833
# 2.382 0.6829
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_11_sr_15.root
# 2.382 0.683
# 2.382 0.682
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_12_sr_15.root
# 2.382 0.682
# 2.382 0.6802
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_13_sr_15.root
# 2.382 0.6799
# 2.382 0.6815
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_14_sr_15.root
# 2.381 0.6815
# 2.382 0.6808
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_15_sr_15.root
# 2.381 0.6808
# 2.382 0.6804
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_16_sr_15.root
# 2.381 0.6804
# 2.382 0.6803
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_17_sr_15.root
# 2.381 0.6804
# 2.382 0.681
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_18_sr_15.root
# 2.381 0.6808
# 2.382 0.6818
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_19_sr_15.root
# 2.381 0.6818
# 2.382 0.6812
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_20_sr_15.root
# 2.381 0.6813
# 2.382 0.6809
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_21_sr_15.root
# 2.381 0.681
# 2.381 0.6809
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_22_sr_15.root
# 2.381 0.6808
# 2.381 0.6818
# /workdir/jupyter/tot_data_taking_data/ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_23_sr_15.root
# <_io.BufferedWriter name='/workdir/jupyter/tot_data_taking_data/datasetID_70_list.pickle'>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ...
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# >WARNING: Status-Bit(s) have been set:
# >WARNING: CommonStatusBits: 0x0000, Channel#3 StatusBits: 0x0000
# >WARNING:    COM_EndpointReached: no endpoint has been reached
# rm: cannot remove '*.root': No such file or directory
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./first_C.so
# In file included from input_line_12:9:
# ././first.C:10:5: error: use of undeclared identifier 'base'
#     base::ProcMgr::instance()->SetTriggeredAnalysis(true);
#     ^
# ././first.C:13:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetHistFilling(4);
#    ^
# ././first.C:16:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcMessage::SetFineLimits(10, 510);
#    ^
# ././first.C:19:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetDefaults(53, 0x2);
#    ^
# ././first.C:24:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetTDCRange(TDCRANGE_START, TDCRANGE_STOP);
#    ^
# ././first.C:29:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TdcProcessor::SetToTCalibr(100, 0.2);
#    ^
# ././first.C:33:4: error: use of undeclared identifier 'hadaq'
#    hadaq::TrbProcessor::SetHUBRange(HUBRANGE_START, HUBRANGE_STOP);
#    ^
# ././first.C:38:4: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#    ^
# ././first.C:38:35: error: use of undeclared identifier 'hadaq'
#    hadaq::HldProcessor* hld = new hadaq::HldProcessor(true, "after_create");
#                                   ^
# ././first.C:76:4: error: use of undeclared identifier 'base'
#    base::ProcMgr::instance()->SetStoreKind(1);
#    ^
# ././first.C:82:30: error: use of undeclared identifier 'hadaq'
# extern "C" void after_create(hadaq::HldProcessor* hld)
#                              ^
# ././first.C:89:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TrbProcessor* trb = hld->GetTRB(k);
#       ^
# ././first.C:98:7: error: use of undeclared identifier 'hadaq'
#       hadaq::TdcProcessor* tdc = hld->GetTDC(k);
#       ^
# Error in <ACLiC>: Dictionary generation failed!
# Info in <TUnixSystem::ACLiC>: creating shared library /workdir/./second_C.so

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')        
plt.scatter(range(0,len(current_list)),current_list)    
plt.xlabel("data set")
plt.ylabel("supply current [A] of all PASTTREC boards 101 (5V layer 2) ")
plt.show()
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k') 
plt.scatter(range(0,len(current_list2)),current_list2)        
plt.xlabel("data set")
plt.ylabel("supply current [A] of PASTTREC board 110 (5V layer 3) ")
plt.show()

plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k') 
plt.scatter(range(0,len(volt_list)),volt_list,alpha=0.3,label = "5V layer 2")
plt.scatter(range(0,len(volt_list2)),volt_list2,alpha=0.3,label = "5V layer 3")      
plt.xlabel("data set")
plt.ylabel("supply voltage [V] of all PASTTREC boards  ")
plt.legend()
plt.show()

# %%
archive(label="ID_{:d}_tot_data_powersupply_trend".format(dataset_id))
# Out:
# archived to ./archive/2020-06-09_18-28-00_tot_data_taking_ID_70_tot_data_powersupply_trend

# %%
import pickle
with open("{:s}/datasetID_{:d}_list.pickle".format(data_dir,dataset_id), 'wb') as fp:
    pickle.dump(data_file_list, fp)  
print(fp)

##################################################
##               slurp root file                ##
##################################################
 
#with open ('/workdir/jupyter/tot_data_taking_data/HV1600V_ptime_15_threshold_50_gain_4_boardsON_23.rootlist.pickle', 'rb') as fp:
 #   data_file_list = pickle.load(fp)
    

#f = ROOT.TFile("/workdir/tree_out.root".format(data_dir))
#tree = f.Get("TDC_1503")
#print("data entries TDC_1503: " + str(tree.GetEntries()))
i = -1
clist = [None]*100
print("data file   ,", "tot_mostprob", "signalcounts", "noisecounts", "sn_ratio", "significance")
    
for data_file in data_file_list:
    i += 1
    #print(data_file)
    f = ROOT.TFile("{:s}".format(data_file))
    tree = f.Get("joint_tree")
    #print("data entries: " + str(tree.GetEntries()))
    ## plot data:
    clist[i] = ROOT.TCanvas("myCanvasName"+str(i),str(data_file),800,600)
    tree.Draw("tot>>htot(300,0,400)","chan > 150300 && chan < 150316")
    tree.Draw("tot>>htot2(300,0,400)","chan > 035300 && chan < 035316","same")    
    clist[i].Draw()
    htot = f.Get("htot")
    htot2 = f.Get("htot2")
    clist[i].SetLogy()
    htot.GetXaxis().SetTitle("ToT [ns]")
    htot.GetYaxis().SetTitle("counts")
    htot.SetTitle(data_file.strip("workdir/jupyter/tot_data_taking_data"))
    htot.SetLineColor(6)
    htot.DrawCopy("")
    htot2.DrawCopy("same")
    tot_mostprob = htot.GetXaxis().GetBinCenter(htot.GetMaximumBin())
    
    signalcounts  = htot.Integral(htot.FindBin(50),htot.GetNbinsX())
    noisecounts   = htot.Integral(1,htot.FindBin(50))
    if noisecounts == 0:
        sn_ratio = -1
        significance = -1
    else:
        sn_ratio = signalcounts/noisecounts
        significance = signalcounts/np.sqrt(signalcounts+noisecounts)
    print(  htot.GetTitle() , "| ",  tot_mostprob,"| ", signalcounts,"| ", noisecounts,"| ", "{:.2f}".format(sn_ratio),"| ", "{:.2f}".format(significance))
# Out:
# <_io.BufferedWriter name='/workdir/jupyter/tot_data_taking_data/datasetID_70_list.pickle'>
# data file   , tot_mostprob signalcounts noisecounts sn_ratio significance
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_0_sr_15. |  131.33333333333331 |  1374.0 |  12.0 |  114.50 |  36.91
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_1_sr_15. |  141.99999999999997 |  1332.0 |  22.0 |  60.55 |  36.20
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_2_sr_15. |  133.99999999999997 |  1351.0 |  13.0 |  103.92 |  36.58
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_3_sr_15. |  127.33333333333333 |  1354.0 |  15.0 |  90.27 |  36.59
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_4_sr_15. |  132.66666666666666 |  1350.0 |  21.0 |  64.29 |  36.46
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_5_sr_15. |  133.99999999999997 |  1281.0 |  11.0 |  116.45 |  35.64
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_6_sr_15. |  128.66666666666666 |  1318.0 |  15.0 |  87.87 |  36.10
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_7_sr_15. |  127.33333333333333 |  1294.0 |  16.0 |  80.88 |  35.75
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_8_sr_15. |  129.99999999999997 |  1284.0 |  11.0 |  116.73 |  35.68
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_9_sr_15. |  132.66666666666666 |  1341.0 |  21.0 |  63.86 |  36.34
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_10_sr_15. |  126.0 |  1361.0 |  20.0 |  68.05 |  36.62
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_11_sr_15. |  124.66666666666667 |  1281.0 |  14.0 |  91.50 |  35.60
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_12_sr_15. |  128.66666666666666 |  1360.0 |  17.0 |  80.00 |  36.65
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_13_sr_15. |  131.33333333333331 |  1358.0 |  17.0 |  79.88 |  36.62
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_14_sr_15. |  133.99999999999997 |  1340.0 |  12.0 |  111.67 |  36.44
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_15_sr_15. |  127.33333333333333 |  1296.0 |  19.0 |  68.21 |  35.74
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_16_sr_15. |  124.66666666666667 |  1290.0 |  17.0 |  75.88 |  35.68
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_17_sr_15. |  128.66666666666666 |  1325.0 |  15.0 |  88.33 |  36.20
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_18_sr_15. |  140.66666666666666 |  1333.0 |  15.0 |  88.87 |  36.31
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_19_sr_15. |  131.33333333333331 |  1351.0 |  29.0 |  46.59 |  36.37
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_20_sr_15. |  133.99999999999997 |  1307.0 |  16.0 |  81.69 |  35.93
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_21_sr_15. |  127.33333333333333 |  1346.0 |  31.0 |  43.42 |  36.27
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_22_sr_15. |  127.33333333333333 |  1425.0 |  17.0 |  83.82 |  37.53
# ID70_HV1600V_ptime_15_thr_30_gain_4_boardsON_23_sr_15. |  127.33333333333333 |  1310.0 |  18.0 |  72.78 |  35.95
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_0_sr_15. |  123.33333333333333 |  1351.0 |  21.0 |  64.33 |  36.47
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_1_sr_15. |  128.66666666666666 |  1369.0 |  15.0 |  91.27 |  36.80
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_2_sr_15. |  126.0 |  1391.0 |  21.0 |  66.24 |  37.02
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_3_sr_15. |  126.0 |  1369.0 |  18.0 |  76.06 |  36.76
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_4_sr_15. |  119.33333333333333 |  1324.0 |  20.0 |  66.20 |  36.12
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_5_sr_15. |  131.33333333333331 |  1355.0 |  20.0 |  67.75 |  36.54
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_6_sr_15. |  126.0 |  1304.0 |  12.0 |  108.67 |  35.95
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_7_sr_15. |  124.66666666666667 |  1379.0 |  15.0 |  91.93 |  36.93
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_8_sr_15. |  128.66666666666666 |  1337.0 |  19.0 |  70.37 |  36.31
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_9_sr_15. |  126.0 |  1376.0 |  16.0 |  86.00 |  36.88
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_10_sr_15. |  132.66666666666666 |  1341.0 |  15.0 |  89.40 |  36.42
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_11_sr_15. |  129.99999999999997 |  1287.0 |  20.0 |  64.35 |  35.60
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_12_sr_15. |  127.33333333333333 |  1349.0 |  12.0 |  112.42 |  36.57
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_13_sr_15. |  124.66666666666667 |  1338.0 |  22.0 |  60.82 |  36.28
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_14_sr_15. |  128.66666666666666 |  1275.0 |  32.0 |  39.84 |  35.27
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_15_sr_15. |  128.66666666666666 |  1324.0 |  13.0 |  101.85 |  36.21
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_16_sr_15. |  127.33333333333333 |  1327.0 |  21.0 |  63.19 |  36.14
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_17_sr_15. |  128.66666666666666 |  1309.0 |  16.0 |  81.81 |  35.96
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_18_sr_15. |  133.99999999999997 |  1349.0 |  16.0 |  84.31 |  36.51
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_19_sr_15. |  131.33333333333331 |  1392.0 |  19.0 |  73.26 |  37.06
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_20_sr_15. |  133.99999999999997 |  1327.0 |  16.0 |  82.94 |  36.21
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_21_sr_15. |  127.33333333333333 |  1378.0 |  15.0 |  91.87 |  36.92
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_22_sr_15. |  126.0 |  1312.0 |  14.0 |  93.71 |  36.03
# ID70_HV1600V_ptime_15_thr_31_gain_4_boardsON_23_sr_15. |  135.33333333333331 |  1327.0 |  14.0 |  94.79 |  36.24
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_0_sr_15. |  124.66666666666667 |  1370.0 |  19.0 |  72.11 |  36.76
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_1_sr_15. |  124.66666666666667 |  1354.0 |  20.0 |  67.70 |  36.53
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_2_sr_15. |  128.66666666666666 |  1450.0 |  20.0 |  72.50 |  37.82
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_3_sr_15. |  127.33333333333333 |  1363.0 |  10.0 |  136.30 |  36.78
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_4_sr_15. |  129.99999999999997 |  1357.0 |  18.0 |  75.39 |  36.60
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_5_sr_15. |  127.33333333333333 |  1259.0 |  18.0 |  69.94 |  35.23
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_6_sr_15. |  131.33333333333331 |  1412.0 |  12.0 |  117.67 |  37.42
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_7_sr_15. |  126.0 |  1386.0 |  16.0 |  86.62 |  37.02
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_8_sr_15. |  127.33333333333333 |  1367.0 |  17.0 |  80.41 |  36.75
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_9_sr_15. |  123.33333333333333 |  1371.0 |  15.0 |  91.40 |  36.83
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_10_sr_15. |  122.0 |  1354.0 |  21.0 |  64.48 |  36.51
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_11_sr_15. |  123.33333333333333 |  1324.0 |  16.0 |  82.75 |  36.17
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_12_sr_15. |  128.66666666666666 |  1402.0 |  14.0 |  100.14 |  37.26
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_13_sr_15. |  124.66666666666667 |  1308.0 |  20.0 |  65.40 |  35.89
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_14_sr_15. |  126.0 |  1411.0 |  18.0 |  78.39 |  37.33
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_15_sr_15. |  128.66666666666666 |  1371.0 |  24.0 |  57.12 |  36.71
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_16_sr_15. |  123.33333333333333 |  1305.0 |  17.0 |  76.76 |  35.89
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_17_sr_15. |  128.66666666666666 |  1270.0 |  13.0 |  97.69 |  35.46
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_18_sr_15. |  129.99999999999997 |  1418.0 |  28.0 |  50.64 |  37.29
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_19_sr_15. |  127.33333333333333 |  1351.0 |  20.0 |  67.55 |  36.49
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_20_sr_15. |  126.0 |  1380.0 |  20.0 |  69.00 |  36.88
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_21_sr_15. |  122.0 |  1331.0 |  16.0 |  83.19 |  36.27
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_22_sr_15. |  115.33333333333333 |  1314.0 |  21.0 |  62.57 |  35.96
# ID70_HV1600V_ptime_15_thr_32_gain_4_boardsON_23_sr_15. |  120.66666666666667 |  1353.0 |  20.0 |  67.65 |  36.51
# Warning in <TClass::Init>: no dictionary for class Event is available
# Warning in <TClass::Init>: no dictionary for class Hit is available

# %%
##################################################
##             overview TDC 0x0351              ##
##################################################
c = ROOT.TCanvas("myCanvasName","The Canvas Title",640,480)

tdc=1503
disp_channels = 65
#tree.Draw("chan:t1","","lego2")
tree.Draw("chan:tot>>tot_meta(1000,-300,800,{:d},{:d},{:d})".format(disp_channels,tdc*100,tdc*100+disp_channels),"","colz")
c.Draw()

# %%
import ROOT
import os
from my_utils import *
from fst import *
import numpy as np
import db 
import pasttrec_ctrl as ptc


data_dir = make_data_dir()

#from ROOT import gInterpreter, gSystem
#gInterpreter.ProcessLine('#include "/workdir/my_event.h"')

import tdc_daq as td


print(data_dir)
for my_board in db.board_list():
    db.enable_board(my_board)    
    db.unset_standby_board(my_board)
    #db.disable_board(my_board)
    #ptc.init_board_by_name(my_board)
    #ptc.set_threshold_for_board_by_name(my_board,5)

ptc.init_active_boards()
td.enable_tdc_channels_of_active_boards()

#set spike rejection for pasttrec tdc channels:
#setup = db.get_setup_json()
#setup["global_settings"]["spike_rejection"] = 33
#print( setup["global_settings"]["spike_rejection"] )
#db.write_setup_json(setup)
#db.write_go4_settings_h()
print(db.board_list())
# Out:
# Welcome to JupyROOT 6.14/04
# /workdir/jupyter/tot_data_taking_data
# ['0014', '0005', '0021', '0022', '0025', '0003', '0026', '0027', '0008', '0004', '0002', '0101', '0028', '0029', '0104', '0017', '0106', '0105', '0016', '0006', '0108', '0011', '0009', '0110', '0013', '0018', '0015', '0030', '0020', '0109', '0103', '0102', '0010', '0023']

# %%
##################################################
##   clear data dir, copy root file or measure fresh    ##
##################################################
import hameg_trb 


#data set 2
#all boards on threshold 30, take_data(time=480)
#spike rejection = 15 ns
#HV=1600
#ptime=10
#pt_gain_list = [ 1, 2, 4 ]
#pt_threshold_list = [ 8, 10, 13, 15, 18, 20, 25, 30, 35, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#########################################################################
#data set 3
#all other boards standby,  take_data(time=960)
#spike rejection = 15 ns
#HV=1600
#ptime=15
#pt_gain_list = [ 1, 2, 4 ]
#pt_threshold_list = [ 8, 10, 13, 15, 18, 20, 25, 30, 35, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#########################################################################
#data set 4
#all other boards standby,  take_data(time=480)
#spike rejection = 30 ns
#HV=16002
#ptime=15
#pt_gain_list = [ 1, 2, 4 ]
#pt_threshold_list = [ 8, 10, 13, 15, 18, 20, 25, 30, 35, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#########################################################################
#data set 5
#all other boards standby,  take_data(time=300)
#spike rejection = 15 ns
#HV=1600
#ptime=15
#pt_gain_list = [ 4 ]
#pt_threshold_list = [ 10, 20, 30, 50 ]
#board_list = [ "0009","0010","0011", "0002","0004","0007"]
#boards_scan_list = ['0010', '0015', '0016', '0017', '0020', '0023', '0030', '0029', '0027', '0025', '0026', '0022', '0003', '0014', '0021', '0018', '0006', '0028', '0008', '0005']

#########################################################################
dataset_id = 67
# 49 same like 48 but with noise shield again on board 007 = 010
# 50, boards on scan for gain 2,4 thr 35 board with shield
# 57, boards on scan for gain 2,4 thr 35 boards 101, 108
# 59, full paramete scan gain+peakingtime+threshold boards 101, 108
# 60,repeat 57: boards on scan for gain 2,4 thr 35 boards 101, 108
# 61 boards on scan for gain 2,4 thr 15,20,30,50 boards 101, 108
# 62 threshold scan for gain 1,2,4 pktime 10,15,20 boards 101, 108

# 66 threshold scan for gain 2 pktime 15 boards 101, 110  
# 67 boards on scan for gain 2,4 thr 20,30,40 boards 101, 110

# 51 board with shield, parameter scan
# 52, boards on scan for gain 2 thr 25,30 board with shield
# MDC settings:
HV=1600
data_taking_duration = 600
# set PASTTREC settings:
# peakintime: 10, 15, 20 (ns)
# gain: 1, 2, 4
# threshold: 1,2,3 .... 127
# spike rejection 10 ,15, 20 ,33,99 all int possible (ns)

#ptime_list = [ 10, 15, 20 ]
ptime_list = [ 15 ]
# set PASTTREC default threshold for the measurement
#pt_gain_list = [  1, 2, 4 ]
pt_gain_list = [2,4]  
#pt_threshold_list = [  15, 20, 30, 50 ]
# pt_threshold_list = [ 10,15,20,25,30,35,40,50,70]
pt_threshold_list = [  20,30 ]
spike_reject_list = [15]
#spike_reject_list = [10, 15, 20, 30]

#board_list = [ "0009","0010","0011", "0002","0004","0007", "0015","0016","0017" ]
board_list = [ "0101","0110"]
boards_to_activate_on_one_step = 1
#boards_scan_list = ['0110']
# boards_scan_list = ['0110', '0011', '0010', '0015', '0016', '0009', '0017', '0020', '0023', '0030', '0110', '0029', '0002', '0027', '0101', '0025', '0004', '0026', '0022', '0003', '0014', '0021', '0018', '0104', '0006', '0028', '0103', '0102', '0008', '0005']
#boards_scan_list = ['0010', '0101', '0011', '0002', '0009', '0004', '0015', '0027', '0016', '0025', '0017', '0026', '0022', '0020', '0003', '0023', '0030', '0014', '0021', '0029', '0018', '0104', '0103', '0006', '0008', '0102', '0028']
#boards_scan_list = ['0010', '0011', '0009', '0015', '0016', '0017', '0020', '0023', '0030', '0029', '0101', '0002', '0004', '0027', '0025', '0026', '0022', '0003', '0014', '0021', '0018', '0104', '0006', '0028']
# boards_scan_list = ['0010', '0009', '0011', '0015', '0016', '0017', '0020', '0023', '0030', '0029', '0027', '0002', '0004', '0025', '0026', '0022', '0003', '0014', '0021', '0018', '0006', '0028', '0008', '0005']
boards_scan_list = ['0014', '0005', '0021', '0022', '0025', '0003', '0026', '0027', '0008', '0004', '0002', '0101', '0029', '0030', '0028', '0023', '0020', '0017', '0016', '0006', '0015', '0010', '0011', '0009']
#boards_scan_list =  db.board_list()

data_file_list = []
current_list = []
volt_list = []
current_list2 = []
volt_list2 = []

#for my_board in db.board_list():
#            db.unset_standby_board(my_board)
message = " total measurement time estimated [h] = {:.2f}".format(data_taking_duration/3600*len(spike_reject_list)*len(ptime_list)*len(pt_gain_list)*len(pt_threshold_list)*len(boards_scan_list)/boards_to_activate_on_one_step)
print(message)
alert(message)

for spike_reject in spike_reject_list:
 setup = db.get_setup_json()
 setup["global_settings"]["spike_rejection"] = spike_reject
 db.write_setup_json(setup)
 db.write_go4_settings_h()
 for ptime in ptime_list: 
  for pt_gain in pt_gain_list:     
   for pt_threshold in pt_threshold_list:    
    for my_board in db.board_list():
        db.set_standby_board(my_board)
    
    iboard = -boards_to_activate_on_one_step
    for p in range(0,int(len(boards_scan_list)/boards_to_activate_on_one_step)): 
        iboard += boards_to_activate_on_one_step
        for my_board in db.board_list():
            for p_act in range(0,boards_to_activate_on_one_step):
                if my_board == boards_scan_list[iboard+p_act]:
                    db.unset_standby_board(my_board)
                    db.enable_board(my_board)
        # enable data taking boards:
        for my_board in board_list:
            db.unset_standby_board(my_board)
            db.enable_board(my_board)
        td.enable_tdc_channels_of_active_boards()
        ptc.init_boards_by_name(db.board_list())    
        #ptc.init_active_boards()
        ptc.init_boards_by_name(board_list, ptime, pt_gain, pt_threshold)   
                        # init_boards_by_name(board_list,pktime=-1,gain=-1,threshold=-1):
        for name in board_list:
            ptc.set_threshold_for_board_by_name(name,pt_threshold)
        print(hameg_trb.get_curr(3), hameg_trb.get_curr(4))
        #take_data(events=20000)
        # uses only trigger by TDC 0350 channel 49 as the reference. 
        # either Scitillator inpot or puls generator input to this channel, needs to be used
        take_data(time=data_taking_duration)
        #import time as time
        #time.sleep(4)
        
        
        current_list += [ hameg_trb.get_curr(3) ]
        volt_list += [ hameg_trb.get_volt(3) ]
        current_list2 += [ hameg_trb.get_curr(4) ]
        volt_list2 += [ hameg_trb.get_volt(4) ] 

        print(hameg_trb.get_curr(3), hameg_trb.get_curr(4))
     # clear_data_dir()
        data_file = "{:s}/ID{:d}_HV{:d}V_ptime_{:d}_thr_{:d}_gain_{:d}_boardsON_{:d}_sr_{:d}.root".format(data_dir,dataset_id,HV,ptime,pt_threshold,pt_gain,iboard,spike_reject)
        print(data_file)
        os.system("cp /workdir/joint_tree.root {:s}".format(data_file))
        data_file_list.append(data_file)

  # write data file list to disk, for later analysis
import pickle
with open("{:s}/datasetID_{:d}_list.pickle".format(data_dir,dataset_id), 'wb') as fp:
    pickle.dump(data_file_list, fp)  
print(fp)
archive(label="ToT_data_taking_ID{:d}".format(dataset_id))
# Out:
#  total measurement time estimated [h] = 16.00
# <script>alert(' total measurement time estimated [h] = 16.00');</script>
# 2.382 2.609
# 2.382 2.598
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_0_sr_15.root
# 2.382 2.597
# 2.382 2.575
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_1_sr_15.root
# 2.382 2.574
# 2.382 2.597
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_2_sr_15.root
# 2.382 2.596
# 2.382 2.611
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_3_sr_15.root
# 2.382 2.609
# 2.382 2.608
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_4_sr_15.root
# 2.382 2.607
# 2.382 2.565
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_5_sr_15.root
# 2.382 2.566
# 2.382 2.612
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_6_sr_15.root
# 2.382 2.612
# 2.382 2.663
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_7_sr_15.root
# 2.382 2.663
# 2.382 2.59
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_8_sr_15.root
# 2.382 2.591
# 2.382 2.646
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_9_sr_15.root
# 2.382 2.646
# 2.382 2.677
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_10_sr_15.root
# 2.382 2.677
# 2.382 2.67
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_11_sr_15.root
# 2.382 2.671
# 2.382 2.68
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_12_sr_15.root
# 2.382 2.679
# 2.381 2.661
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_13_sr_15.root
# 2.382 2.661
# 2.382 2.656
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_14_sr_15.root
# 2.382 2.654
# 2.382 2.664
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_15_sr_15.root
# 2.382 2.663
# 2.382 2.68
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_16_sr_15.root
# 2.382 2.68
# 2.382 2.664
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_17_sr_15.root
# 2.382 2.665
# 2.382 2.697
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_18_sr_15.root
# 2.382 2.697
# 2.381 2.691
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_19_sr_15.root
# 2.381 2.691
# 2.381 2.671
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_20_sr_15.root
# 2.382 2.67
# 2.381 2.69
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_21_sr_15.root
# 2.381 2.69
# 2.381 2.683
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_22_sr_15.root
# 2.381 2.682
# 2.381 2.688
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_2_boardsON_23_sr_15.root
# 2.382 2.688
# 2.382 2.692
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_0_sr_15.root
# 2.382 2.691
# 2.382 2.681
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_1_sr_15.root
# 2.382 2.681
# 2.382 2.669
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_2_sr_15.root
# 2.382 2.668
# 2.382 2.681
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_3_sr_15.root
# 2.382 2.681
# 2.382 2.671
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_4_sr_15.root
# 2.382 2.673
# 2.382 2.668
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_5_sr_15.root
# 2.382 2.668
# 2.382 2.68
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_6_sr_15.root
# 2.382 2.68
# 2.382 2.682
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_7_sr_15.root
# 2.382 2.688
# 2.382 2.647
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_8_sr_15.root
# 2.381 2.651
# 2.382 1.302
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_9_sr_15.root
# 2.381 1.302
# 2.382 2.707
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_10_sr_15.root
# 2.381 2.707
# 2.382 2.694
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_11_sr_15.root
# 2.381 2.694
# 2.382 2.677
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_12_sr_15.root
# 2.381 2.678
# 2.382 2.673
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_13_sr_15.root
# 2.381 2.673
# 2.382 2.462
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_14_sr_15.root
# 2.381 2.46
# 2.382 2.451
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_15_sr_15.root
# 2.381 2.451
# 2.382 2.42
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_16_sr_15.root
# 2.381 2.42
# 2.382 2.687
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_17_sr_15.root
# 2.381 2.686
# 2.382 1.086
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_18_sr_15.root
# 2.381 1.086
# 2.382 1.029
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_19_sr_15.root
# 2.381 1.028
# 2.382 0.9931
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_20_sr_15.root
# 2.381 0.9927
# 2.382 1.006
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_21_sr_15.root
# 2.381 1.005
# 2.381 0.9902
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_22_sr_15.root
# 2.381 0.9898
# 2.381 0.9511
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_2_boardsON_23_sr_15.root
# 2.382 0.9512
# 2.382 0.9767
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_0_sr_15.root
# 2.382 0.9743
# 2.382 0.9237
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_1_sr_15.root
# 2.382 0.9233
# 2.382 0.9171
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_2_sr_15.root
# 2.382 0.9172
# 2.382 0.9063
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_3_sr_15.root
# 2.381 0.9063
# 2.382 0.8819
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_4_sr_15.root
# 2.381 0.8819
# 2.382 0.8463
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_5_sr_15.root
# 2.381 0.8462
# 2.382 0.8415
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_6_sr_15.root
# 2.381 0.8414
# 2.382 0.8497
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_7_sr_15.root
# 2.381 0.8497
# 2.382 2.442
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_8_sr_15.root
# 2.381 2.436
# 2.381 2.454
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_9_sr_15.root
# 2.381 2.454
# 2.381 2.46
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_10_sr_15.root
# 2.381 2.459
# 2.381 2.417
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_11_sr_15.root
# 2.381 2.416
# 2.381 2.505
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_12_sr_15.root
# 2.381 2.503
# 2.381 2.435
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_13_sr_15.root
# 2.381 2.433
# 2.381 2.461
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_14_sr_15.root
# 2.381 2.461
# 2.381 2.406
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_15_sr_15.root
# 2.381 2.394
# 2.381 2.32
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_16_sr_15.root
# 2.381 2.322
# 2.381 2.523
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_17_sr_15.root
# 2.381 2.52
# 2.381 2.386
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_18_sr_15.root
# 2.381 2.382
# 2.381 2.509
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_19_sr_15.root
# 2.381 2.501
# 2.381 2.469
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_20_sr_15.root
# 2.381 2.466
# 2.381 2.43
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_21_sr_15.root
# 2.381 2.426
# 2.381 2.446
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_22_sr_15.root
# 2.381 2.446
# 2.381 2.416
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_20_gain_4_boardsON_23_sr_15.root
# 2.382 2.413
# 2.382 2.399
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_0_sr_15.root
# 2.382 2.402
# 2.382 2.381
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_1_sr_15.root
# 2.382 2.382
# 2.382 2.502
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_2_sr_15.root
# 2.382 2.495
# 2.382 2.494
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_3_sr_15.root
# 2.382 2.494
# 2.382 2.394
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_4_sr_15.root
# 2.381 2.394
# 2.382 2.533
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_5_sr_15.root
# 2.381 2.533
# 2.382 2.534
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_6_sr_15.root
# 2.381 2.534
# 2.382 2.536
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_7_sr_15.root
# 2.381 2.536
# 2.381 2.502
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_8_sr_15.root
# 2.381 2.5
# 2.381 2.568
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_9_sr_15.root
# 2.381 2.569
# 2.381 2.555
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_10_sr_15.root
# 2.381 2.555
# 2.381 2.475
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_11_sr_15.root
# 2.381 2.475
# 2.381 2.401
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_12_sr_15.root
# 2.381 2.392
# 2.381 2.421
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_13_sr_15.root
# 2.381 2.421
# 2.381 2.402
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_14_sr_15.root
# 2.381 2.408
# 2.381 2.32
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_15_sr_15.root
# 2.381 2.311
# 2.381 2.355
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_16_sr_15.root
# 2.381 2.348
# 2.381 2.363
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_17_sr_15.root
# 2.381 2.363
# 2.381 2.374
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_18_sr_15.root
# 2.381 2.375
# 2.381 2.093
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_19_sr_15.root
# 2.381 2.092
# 2.381 2.585
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_20_sr_15.root
# 2.381 2.585
# 2.381 2.578
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_21_sr_15.root
# 2.381 2.578
# 2.381 2.597
# /workdir/jupyter/tot_data_taking_data/ID67_HV1600V_ptime_15_thr_30_gain_4_boardsON_22_sr_15.root
# 2.381 2.596

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')        
plt.scatter(range(0,len(current_list)),current_list)    
plt.xlabel("data set")
plt.ylabel("supply current [A] of all PASTTREC boards (5V) ")
plt.show()

plt.scatter(range(0,len(current_list2)),current_list2)        
plt.xlabel("data set")
plt.ylabel("supply current [A] of PASTTREC board 108 (5V) ")
plt.show()

plt.scatter(range(0,len(volt_list)),volt_list)
plt.scatter(range(0,len(volt_list2)),volt_list2)        
plt.xlabel("data set")
plt.ylabel("supply voltage [V] of all / 108 PASTTREC board  ")
plt.show()

# %%
import pickle
with open("{:s}/datasetID_{:d}_list.pickle".format(data_dir,dataset_id), 'wb') as fp:
    pickle.dump(data_file_list, fp)  
print(fp)

##################################################
##               slurp root file                ##
##################################################
 
#with open ('/workdir/jupyter/tot_data_taking_data/HV1600V_ptime_15_threshold_50_gain_4_boardsON_23.rootlist.pickle', 'rb') as fp:
 #   data_file_list = pickle.load(fp)
    

#f = ROOT.TFile("/workdir/tree_out.root".format(data_dir))
#tree = f.Get("TDC_1503")
#print("data entries TDC_1503: " + str(tree.GetEntries()))
i = -1
clist = [None]*100
print("data file   ,", "tot_mostprob", "signalcounts", "noisecounts", "sn_ratio", "significance")
    
for data_file in data_file_list:
    i += 1
    #print(data_file)
    f = ROOT.TFile("{:s}".format(data_file))
    tree = f.Get("joint_tree")
    #print("data entries: " + str(tree.GetEntries()))
    ## plot data:
    clist[i] = ROOT.TCanvas("myCanvasName"+str(i),str(data_file),800,600)
    tree.Draw("tot>>htot(300,0,400)","chan > 150300 && chan < 150316")
    tree.Draw("tot>>htot2(300,0,400)","chan > 035300 && chan < 035316","same")    
    clist[i].Draw()
    htot = f.Get("htot")
    htot2 = f.Get("htot2")
    clist[i].SetLogy()
    htot.GetXaxis().SetTitle("ToT [ns]")
    htot.GetYaxis().SetTitle("counts")
    htot.SetTitle(data_file.strip("workdir/jupyter/tot_data_taking_data"))
    htot.SetLineColor(6)
    htot.DrawCopy("")
    htot2.DrawCopy("same")
    tot_mostprob = htot.GetXaxis().GetBinCenter(htot.GetMaximumBin())
    
    signalcounts  = htot.Integral(htot.FindBin(50),htot.GetNbinsX())
    noisecounts   = htot.Integral(1,htot.FindBin(50))
    if noisecounts == 0:
        sn_ratio = -1
        significance = -1
    else:
        sn_ratio = signalcounts/noisecounts
        significance = signalcounts/np.sqrt(signalcounts+noisecounts)
    print(  htot.GetTitle() , "| ",  tot_mostprob,"| ", signalcounts,"| ", noisecounts,"| ", "{:.2f}".format(sn_ratio),"| ", "{:.2f}".format(significance))

# %%
##################################################
##             overview TDC 0x0351              ##
##################################################
c = ROOT.TCanvas("myCanvasName","The Canvas Title",640,480)

tdc=1503
disp_channels = 65
#tree.Draw("chan:t1","","lego2")
tree.Draw("chan:tot>>tot_meta(1000,-300,800,{:d},{:d},{:d})".format(disp_channels,tdc*100,tdc*100+disp_channels),"","colz")
c.Draw()

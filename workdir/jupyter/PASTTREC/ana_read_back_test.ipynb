# %%
import numpy as np
from matplotlib import pyplot as plt
from my_utils import *
from sigproc_kit import *
import time


from fst import *
from my_utils import *

# %%
data_list = unpickle("/workdir/jupyter/PASTTREC/cosy19_ana_data/data_list.pickle")
# Out:
# loading from /workdir/jupyter/PASTTREC/cosy19_ana_data/data_list.pickle

# %%
dataset = data_list[306]

plt.plot(dataset["time"],dataset["LVDS"])
plt.plot(dataset["time"],10*dataset["UFSD"])
plt.plot(dataset["time"],dataset["analog"])
plt.show()

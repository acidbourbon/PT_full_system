# %%
import pasttrec_ctrl_vova_latest as ptc
import time
threshold = 1
pktime = 10
gain = 2
#board = "80111"
boards = ["80121","80122"]
for board in boards:
    ptc.init_board_by_name(board,10,4,threshold)
#ptc.found_baselines_for_board(board)
TDC = "0x1820"
for bl in range(0,15):
    print(bl)
    #ptc.set_threshold_for_board_by_name("80121",bl)
    ptc.set_all_baselines_to_same_value( TDC, bl)
    time.sleep(1)
# Out:
# Welcome to JupyROOT 6.14/04
# 43520
# 43530
# 43530
# 43520
# 43530
# 43530
# 0
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 1
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 2
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 3
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 4
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 5
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 6
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 7
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 8
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 9
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 10
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 11
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 12
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 43530
# 13
# 43530
# 43530
# 43530
# ...
